# %%
import numpy as np
from datetime import datetime, timedelta
import pylab
import matplotlib.pyplot as plt
from matplotlib import gridspec
import pandas as pd
import math
import pandas.tseries.offsets as ofs
import scipy as sc 

from sklearn.linear_model import LinearRegression
from scipy import stats
import statsmodels.api as sm
from statsmodels.tsa import stattools

from lection_utils import qualityMAPE, get_autoregrmatrix

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7816/2002997379.py in <module>
#      14 from statsmodels.tsa import stattools
#      15
# ---> 16 from lection_utils import qualityMAPE, get_autoregrmatrix
#      17
#      18 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'lection_utils'

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aromanenko/ATSF/main/data/energy_consumption.csv', parse_dates=['Date'])
ts = df[df.id == 5].drop(columns='id').set_index('Date')['2011-01-01':'2014-01-01']

# %%
ts.head(3)
# Out:
#             EnergyConsumption  Temp1  Temp2  Temp3  Temp4  Temp5  Temp6  \
# Date
# 2011-01-01         135936.126   -6.0   -4.7    NaN    NaN    NaN    NaN
# 2011-01-02         136629.379   -7.6   -5.7    NaN    NaN    NaN    NaN
# 2011-01-03         140293.989   -6.3   -5.9    NaN    NaN    NaN    NaN
#
#             Temp7  Saturday  Sunday  Temp1_South_Less  Temp2_South_Less  \
# Date
# 2011-01-01    NaN       1.0     0.0               NaN               NaN
# 2011-01-02    NaN       0.0     1.0               NaN               NaN
# 2011-01-03    NaN       0.0     1.0               NaN               NaN
#
#             Temp3_South_Less  Temp4_South_Less  Temp1_South_Gr  \
# Date
# 2011-01-01               NaN               NaN             NaN
# 2011-01-02               NaN               NaN             NaN
# 2011-01-03               NaN               NaN             NaN
#
#             Temp2_South_Gr  Temp3_South_Gr  Temp4_South_Gr
# Date
# 2011-01-01             NaN             NaN             NaN
# 2011-01-02             NaN             NaN             NaN
# 2011-01-03             NaN             NaN             NaN
